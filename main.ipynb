# %%
import os
import random
import shutil
import cv2 as cv
import numpy as np

# %%
##  The datasets was separated using Holdout in a Python file "splitdata_holdout.ipynb"using Jupyter notebook

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
! git clone 'https://github.com/ultralytics/yolov5' '/content/drive/MyDrive/projectDL'
# %cd /content/drive/MyDrive
# %cd /content/drive/MyDrive/deep_learning_project

# !pip install -U -r requirements.txt  # install

# %%
# !pip install Pillow==9.0.0

# %%
import torch
import utils
display = utils.notebook_init()  # checks

# %%
# Weights & Biases  (optional)
# %pip install -q wandb
import wandb
#wandb.logout()

# %%
# !python train.py --img 640  --batch 2 --epochs 300 --cfg yolov5l.yaml --data /content/drive/MyDrive/deep_learning_project/data/custom_data_cfg.yaml --weights 'yolov5s.pt' --nosave --cache

# %%
 # !python detect.py --weights /content/drive/MyDrive/deep_learning_project/runs/train/exp/weights/last.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/projectDL/image2.jpeg

# %%
# !python /content/drive/MyDrive/deep_learning_project/test.py --weights /content/drive/MyDrive/deep_learning_project/runs/train/exp/weights/last.pt --data /content/drive/MyDrive/deep_learning_project/data/custom_data_cfg.yaml --img 640

# %%
# !python test.py  --data custom_data_cfg.yaml  --img 640  --conf 0.040 --weights /content/drive/MyDrive/projectDL/runs/train/exp2/weights/last.pt
